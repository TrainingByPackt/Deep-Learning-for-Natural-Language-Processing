# %%
import pandas as pd
import numpy as np
from keras.models import Model, Sequential
from keras.layers import LSTM, Dense,Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("spam.csv", encoding="latin")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df = df[["v1","v2"]]

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df["v1"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: v1, dtype: int64

# %%
# get X as feature and Y as target

# %%
lab_map = {"ham":0, "spam":1}

# %%
Y = df["v1"].map(lab_map).values

# %%
Y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
X = df["v2"].values

# %%
X
# Out:
# array(['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#        'Ok lar... Joking wif u oni...',
#        "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#        ..., 'Pity, * was in mood for that. So...any other suggestions?',
#        "The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free",
#        'Rofl. Its true to its name'], dtype=object)

# %%
# convert to sequences
# pad sequence
# train

# %%
max_words = 100
mytokenizer = Tokenizer(nb_words=max_words,lower=True, split=" ")
# Out:
# /Users/tanuj.jain/anaconda3/envs/packt_env/lib/python3.6/site-packages/keras_preprocessing/text.py:178: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
mytokenizer.fit_on_texts(X)

# %%
text_tokenized = mytokenizer.texts_to_sequences(X)

# %%
text_tokenized
# Out:
# [[50, 64, 8, 89, 67, 58],
#  [46, 6],
#  [47, 8, 19, 4, 2, 71, 2, 2, 73],
#  [6, 23, 6, 57],
#  [1, 98, 69, 2, 69],
#  [67, 21, 7, 38, 87, 55, 3, 44, 12, 14, 85, 46, 2, 68, 2],
#  [11, 9, 25, 55, 2, 36, 10, 10, 55],
#  [72, 13, 72, 13, 12, 51, 2, 13],
#  [72, 4, 3, 17, 2, 2, 16, 64],
#  [13, 96, 26, 6, 81, 2, 2, 5, 36, 12, 47, 16, 5, 96, 47, 18],
#  [30, 32, 77, 7, 1, 98, 70, 2, 80, 40, 93, 88],
#  [2, 48, 2, 73, 7, 68, 2, 65, 92, 42],
#  [3, 17, 4, 47, 8, 91, 73, 5, 2, 38],
#  [12, 5, 2, 3, 12, 40, 1, 1, 97, 13, 12, 7, 33, 11, 3, 17, 7, 4, 29, 51],
#  [1, 17, 4, 18, 36, 33],
#  [2, 13, 5, 8, 5, 73, 26, 89],
#  [93, 30],
#  [6, 49, 19, 1, 69, 1],
#  [34, 5, 6, 5, 61],
#  [94, 5, 73, 35, 2, 2],
#  [9, 20, 49, 3],
#  [75, 2, 12, 19, 64],
#  [23, 57, 45, 9, 90],
#  [1, 11, 57, 1, 50, 82, 82, 6, 35],
#  [38, 1, 28, 44, 36, 3],
#  [37, 2, 4, 30, 25, 40, 9, 69, 30, 45, 1],
#  [13, 23],
#  [3, 5, 22, 3, 3, 4, 22, 3, 13, 27, 3, 11, 66],
#  [30, 87, 5, 21, 78, 3, 54, 34],
#  [1, 20, 53, 14, 55],
#  [85, 25, 51, 20, 3, 25, 80, 10, 26, 20, 70, 2, 36],
#  [69,
#   58,
#   8,
#   29,
#   19,
#   7,
#   59,
#   89,
#   52,
#   7,
#   95,
#   59,
#   55,
#   7,
#   69,
#   58,
#   44,
#   8,
#   20,
#   19,
#   24,
#   39,
#   50,
#   67,
#   25,
#   3],
#  [93, 99, 10, 80, 3],
#  [12, 15, 36, 5, 15, 51, 20, 3, 37, 17, 4],
#  [12, 13, 2, 13, 96, 33, 32, 76, 26, 38, 34, 3, 92, 38, 3, 33, 25, 32],
#  [46, 1, 50, 77, 29, 5, 57, 1, 75, 2, 18, 24, 9, 29],
#  [78, 3, 54, 45, 11],
#  [1, 86, 5, 18, 11],
#  [82, 6],
#  [3, 7, 49, 50, 1, 59, 37, 2, 86, 34, 2, 27, 25, 20, 30, 2, 26],
#  [50, 36, 1, 37, 2, 32, 27, 17, 4],
#  [1, 2, 99, 3, 1, 70, 3, 1, 79, 3, 1, 3, 24, 15, 51, 1, 66, 3, 11],
#  [39, 2, 16, 3, 13, 92, 2, 91, 12, 4, 47, 96, 47, 16, 21, 12],
#  [22, 3],
#  [1, 3, 55, 13, 1, 62, 43, 41],
#  [38],
#  [3, 31, 8],
#  [75, 18],
#  [34, 27, 14, 1, 4],
#  [6, 98, 54, 49, 1, 62, 1, 70, 2, 50, 2, 5, 1, 30, 25, 4, 22, 12],
#  [53, 3, 80, 10, 63, 3, 10, 8],
#  [4, 55, 43, 41, 4, 9, 7, 3, 4, 12, 43, 41],
#  [93, 4, 24, 29, 91],
#  [1,
#   20,
#   3,
#   23,
#   76,
#   13,
#   1,
#   3,
#   14,
#   1,
#   59,
#   5,
#   1,
#   7,
#   3,
#   23,
#   80,
#   5,
#   30,
#   83,
#   1,
#   7,
#   98,
#   17,
#   2,
#   30,
#   83,
#   1,
#   30,
#   83,
#   13,
#   59,
#   23],
#  [5, 7, 5, 26, 92],
#  [27, 3, 54, 53, 52, 21, 43, 41],
#  [12, 19, 9, 16, 21, 51, 42, 47, 94, 52],
#  [83, 78, 16, 8],
#  [99, 3],
#  [7, 52, 15],
#  [13, 17, 2, 44, 4, 12, 18, 13, 77, 1, 9, 10],
#  [56, 22],
#  [61, 4, 15],
#  [83, 11, 14, 46, 34, 1, 60, 76, 21],
#  [46, 1, 90, 69, 69, 33, 1],
#  [72, 4, 1, 62, 2, 3, 20, 15, 13, 38, 3, 22, 36, 4, 16],
#  [88, 9, 65, 33, 6, 12, 10, 68, 40, 2, 51, 35, 24, 10],
#  [35, 4, 2, 26, 2, 73, 2],
#  [3, 80, 5, 14, 36, 51, 15],
#  [1, 2, 18, 40],
#  [57, 28],
#  [22, 3],
#  [29, 77, 21, 27],
#  [93, 93, 22, 3, 49, 3],
#  [6, 28, 16, 10, 21],
#  [1, 62, 16, 10, 3, 47],
#  [1, 62, 4, 7, 33, 3, 36, 7],
#  [1, 55, 3, 24, 62],
#  [25, 43, 41, 26, 53],
#  [61, 25, 5, 85, 12, 4, 49, 27, 67],
#  [83, 78, 16],
#  [93, 3, 16, 10, 37, 21],
#  [46, 1, 62, 18, 5, 2, 77],
#  [3, 33, 32, 8, 5, 15, 20],
#  [84],
#  [1, 16, 3, 98, 17, 34, 10],
#  [12, 45, 6, 18, 1, 64, 79, 19, 7, 74, 7, 30, 1, 51, 11],
#  [1, 2, 68, 2, 14, 24, 87, 23, 30, 87, 8, 29, 5, 1, 8, 51, 11],
#  [30, 25, 44, 2, 14, 85],
#  [60, 35, 47],
#  [27, 2],
#  [83,
#   2,
#   32,
#   4,
#   9,
#   14,
#   46,
#   34,
#   39,
#   1,
#   8,
#   7,
#   20,
#   1,
#   15,
#   7,
#   20,
#   51,
#   11,
#   63,
#   7,
#   20,
#   83],
#  [8, 8, 45, 55, 45, 6, 85, 2, 86, 6],
#  [16, 91, 18, 72, 3, 17, 4, 26],
#  [2, 1, 64, 58, 8, 6],
#  [13, 47, 9, 2, 32, 71, 5, 2, 2, 31, 7],
#  [6],
#  [1, 86, 45, 39, 39, 17, 15, 2],
#  [46,
#   18,
#   21,
#   18,
#   12,
#   4,
#   15,
#   4,
#   20,
#   1,
#   17,
#   29,
#   23,
#   79,
#   2,
#   31,
#   77,
#   89,
#   20,
#   12,
#   6],
#  [98, 71, 10, 1, 17, 2],
#  [35, 72, 72, 61, 28, 1, 44, 6],
#  [30, 85, 12, 4, 2, 7, 17, 25],
#  [72, 13, 72, 13, 12, 51, 2, 13],
#  [1, 2, 27, 20, 1, 1, 44, 18, 7, 11, 2, 18, 11, 14, 85],
#  [11, 7, 66, 3],
#  [4, 12, 13, 18, 11, 3, 12, 11],
#  [78, 3, 44, 45, 1, 31],
#  [49, 11, 20, 11, 4],
#  [1, 54, 11, 59, 55, 3, 25, 32, 57, 1, 62, 5, 74, 2],
#  [94, 1],
#  [53, 9, 5, 15, 5],
#  [75, 12, 3],
#  [30, 46, 14, 1, 55, 19, 24, 1, 6, 55, 6, 25],
#  [39, 22, 2, 3, 20, 3, 4, 16, 64],
#  [35, 30, 30, 89, 18, 23],
#  [72, 1, 11, 11, 1, 95, 10, 42, 95, 10, 2, 39, 67],
#  [3, 22, 4, 6, 17, 19, 26, 4, 42, 2, 4, 19],
#  [39, 12],
#  [11, 37, 10, 20, 5, 23],
#  [13, 12, 2, 16],
#  [13, 96, 38, 59, 18, 40, 9, 91, 2, 6, 16, 48],
#  [9, 11, 51, 20],
#  [22, 2, 4, 34, 3, 17, 4, 16],
#  [1, 62, 75, 2, 88, 33, 32, 64, 29],
#  [63],
#  [56, 33, 27],
#  [37,
#   23,
#   20,
#   3,
#   54,
#   1,
#   37,
#   4,
#   71,
#   25,
#   2,
#   23,
#   61,
#   3,
#   94,
#   17,
#   2,
#   8,
#   1,
#   17,
#   18,
#   3,
#   8,
#   5,
#   23,
#   12,
#   20,
#   1],
#  [22, 3, 67, 8],
#  [49, 81, 6, 6, 81, 10, 81, 63, 38, 10, 4, 16, 63, 48],
#  [93, 93, 49, 14],
#  [30, 77],
#  [33, 16],
#  [11],
#  [4, 34, 6, 54, 5, 9, 8, 73, 2],
#  [70, 19, 31, 70, 19, 35, 5, 2],
#  [1, 64],
#  [69, 9, 67, 3, 16, 7],
#  [38, 38, 1, 33, 51],
#  [25, 48, 5, 12, 47, 71, 50, 2, 34, 6, 31, 6, 36],
#  [58, 1, 2, 1, 8, 1, 4, 24, 55, 25],
#  [93, 71, 10, 45, 18, 5],
#  [12, 13],
#  [4, 31, 15, 42, 8],
#  [1, 54, 3, 22, 28, 3, 5, 87],
#  [86, 25, 18, 5],
#  [5, 9, 12],
#  [3, 2, 11, 71, 30, 7, 2, 48, 6, 92, 84, 2],
#  [33, 16, 8, 91, 33, 48, 23],
#  [93, 1, 11, 20],
#  [58, 8],
#  [5, 9, 7, 30, 1, 17],
#  [1, 9, 38, 79, 19, 50, 19],
#  [46, 35, 92],
#  [72, 13, 72, 13, 12, 51, 2, 13],
#  [3,
#   22,
#   18,
#   5,
#   5,
#   18,
#   11,
#   7,
#   45,
#   1,
#   11,
#   3,
#   22,
#   51,
#   20,
#   52,
#   1,
#   15,
#   11,
#   3,
#   57,
#   11,
#   22,
#   52,
#   4,
#   63,
#   15,
#   12,
#   10,
#   15,
#   1,
#   86,
#   24,
#   1,
#   55,
#   51,
#   3,
#   37,
#   55,
#   7,
#   7,
#   45,
#   11,
#   63,
#   9,
#   3,
#   7,
#   1,
#   74],
#  [22, 3, 29],
#  [30, 11, 21],
#  [11,
#   66,
#   53,
#   22,
#   3,
#   3,
#   31,
#   2,
#   20,
#   88,
#   22,
#   3,
#   3,
#   22,
#   3,
#   4,
#   56,
#   27,
#   3,
#   15,
#   10,
#   22,
#   3,
#   10],
#  [3, 17, 4, 12, 3, 16, 21, 2],
#  [3, 22, 4, 6, 17, 19, 26, 4, 42, 2, 4, 19],
#  [12, 10, 1, 79, 3, 7, 1, 3, 7, 1, 20, 3, 8],
#  [7, 12, 11, 1, 17, 64, 8],
#  [30, 23, 8, 66, 36, 3, 30, 65, 1, 36, 3, 3, 10, 23],
#  [84, 9, 3, 2, 32, 92, 26, 38, 86, 6, 84, 68, 84, 2],
#  [35, 9, 18, 5, 6, 4, 19, 35, 34, 6, 27, 25, 18, 35, 96],
#  [1, 51, 35, 18],
#  [39, 22, 2, 3, 20, 3, 17, 4, 16, 64],
#  [9, 2, 91],
#  [1, 5, 24, 86, 3],
#  [14, 8, 52, 15],
#  [1, 79, 38, 7],
#  [58, 63, 2, 28, 50, 42, 47, 16, 6, 2],
#  [53, 63, 3],
#  [3, 11, 6, 4, 61, 7, 36],
#  [30, 11, 21, 17, 4, 56],
#  [10, 54, 45, 58, 5, 23, 28, 5, 16],
#  [6, 85, 75, 2, 5],
#  [52, 11, 22, 12, 5, 7, 32, 87, 43, 41, 23, 47, 2, 50, 7, 20, 43, 41],
#  [71, 34, 95, 92, 10, 54, 23, 1, 28, 17, 8],
#  [3, 37, 2, 55, 2, 54, 34, 3, 36, 5, 92, 47, 36, 26, 38],
#  [3, 11, 36, 5, 15, 1, 62, 8, 79, 45, 5, 15, 5, 7, 14, 11, 17, 4],
#  [38, 6, 28, 10],
#  [46, 1, 62, 4, 7, 33, 3, 36, 7],
#  [69, 33, 3],
#  [75, 18],
#  [22, 3, 20, 25, 87, 20, 12, 11, 21, 69, 10],
#  [32, 67, 8, 4],
#  [16, 91, 18, 72, 3, 17, 4, 26],
#  [17, 3, 58, 34, 25, 1, 33, 31, 14, 21],
#  [1, 77, 1, 50, 24, 11, 99, 6, 45, 95, 93],
#  [22, 3, 52, 48],
#  [30, 83, 5, 15, 20, 94, 8, 3, 4, 2, 10, 3, 17, 4, 29, 51, 29, 27, 17, 4],
#  [1, 5],
#  [14, 33, 84, 18, 1, 95, 36, 20, 33, 32, 2, 12],
#  [49, 22, 3, 8, 12, 5, 37, 3, 4, 65],
#  [4, 65],
#  [6, 58, 20],
#  [9, 13, 23, 1, 3, 29],
#  [61, 49, 9, 13, 1, 1, 28, 86, 3, 12, 4, 24, 1, 17, 2, 73, 87, 34, 6, 28],
#  [14, 43, 41, 3, 29],
#  [1, 3, 43, 41],
#  [21, 23, 73, 10, 45, 6, 34, 6, 28, 66],
#  [13, 76, 43, 41, 13, 9, 43, 41, 13, 9, 43, 41],
#  [],
#  [6, 16, 10, 29, 46],
#  [55, 1],
#  [72, 1, 11, 11, 1, 95, 10, 42, 95, 10, 2, 39, 67],
#  [],
#  [3, 88, 43, 41, 26, 5],
#  [1, 23, 31],
#  [44, 3, 4, 27, 17, 4],
#  [77, 23, 39, 28],
#  [93, 93, 56],
#  [49],
#  [22, 3, 77, 21],
#  [5, 72, 13],
#  [1, 5],
#  [58, 61, 56],
#  [1, 17, 2, 97, 36],
#  [3,
#   1,
#   3,
#   28,
#   13,
#   41,
#   21,
#   2,
#   25,
#   24,
#   34,
#   1,
#   28,
#   10,
#   54,
#   24,
#   45,
#   3,
#   27,
#   32,
#   3,
#   22],
#  [46, 38, 97, 35, 63],
#  [67, 9, 33, 8, 3, 28, 20, 2, 5, 8, 7, 14, 2],
#  [83, 78, 16],
#  [6, 15, 25, 4, 64, 82, 1, 25, 23],
#  [48, 50, 73, 2, 38, 88, 48, 64, 42],
#  [34, 3, 16, 10, 37, 79, 2, 2],
#  [33, 6, 35, 9, 35, 19, 4, 19, 52, 47, 73, 76, 35],
#  [],
#  [9, 57, 24, 57],
#  [56, 21, 64, 1, 62, 44],
#  [31, 8, 7, 2, 43, 41, 7, 29],
#  [39, 22, 75, 2, 91],
#  [83, 30],
#  [9, 8],
#  [71, 88, 6, 28, 4, 26, 61, 44, 2, 6, 42, 37, 92, 36],
#  [1, 17, 14, 23, 43, 41, 60],
#  [26, 32, 4, 55, 29, 5, 84, 18, 5],
#  [22, 3, 45, 3],
#  [24, 5, 23, 94, 36, 35, 37, 30],
#  [6, 17, 4, 9, 19, 36, 6, 52, 81, 35, 23, 16, 18],
#  [18, 11, 23, 1],
#  [10],
#  [38, 38, 37, 18, 20, 59, 2, 32, 24, 20],
#  [1, 6, 30, 21, 24, 1, 55, 6, 6, 42, 88, 30],
#  [6, 98, 20],
#  [1, 1, 17, 5, 1, 1, 17, 26, 94, 17, 5],
#  [1, 3, 2, 16, 21, 46],
#  [8],
#  [14, 46, 57, 1, 7, 17, 14, 76, 5, 63, 3, 44, 3, 22, 17, 4, 56],
#  [35, 15, 26, 47, 19, 73, 2],
#  [7],
#  [35, 6, 97, 14, 9, 89, 15, 89, 17, 65, 90],
#  [53, 3, 49, 22, 3],
#  [9, 7, 5, 20, 5, 9, 4, 24, 45, 14, 2, 3, 17, 2, 2, 31, 13],
#  [30, 87, 54, 45],
#  [98, 14, 2, 32, 3, 31, 87, 30, 37, 21, 52],
#  [23, 2, 5],
#  [22, 3, 1, 79, 3],
#  [39, 2, 3, 13, 92, 2, 91, 15, 4, 71, 92, 26, 16, 21],
#  [2, 4, 45, 22, 3, 8, 88, 27, 3],
#  [],
#  [30, 75, 18, 11, 21, 11, 25, 6],
#  [11, 38, 8, 10, 34, 35],
#  [1, 62, 70, 2, 26, 86, 10, 71, 2, 71, 29, 2, 71, 84],
#  [3, 60, 36],
#  [4, 57],
#  [25, 85, 2, 31, 4, 15],
#  [35, 47, 50, 2, 2, 21, 84, 73, 84, 2],
#  [5, 1, 37, 2],
#  [31, 5, 18, 13, 96, 7, 40, 9, 47, 15],
#  [60, 2, 52, 91],
#  [12, 65, 60, 8, 4, 3, 55, 5, 7, 13, 29, 5],
#  [15, 2, 32, 37, 42, 21, 68, 2],
#  [1, 72, 97],
#  [38, 11, 25],
#  [],
#  [99, 2, 8, 5],
#  [78, 86, 3, 8, 4],
#  [37, 14, 23, 53, 15, 27, 3, 55],
#  [51, 51, 8, 8],
#  [3, 58, 4],
#  [6],
#  [46, 1, 12, 49],
#  [],
#  [1, 11, 85, 52, 48, 34, 3, 31, 15, 10, 54, 7, 78],
#  [93, 1, 60, 76, 57, 34, 11, 52],
#  [46],
#  [36,
#   11,
#   53,
#   81,
#   6,
#   44,
#   19,
#   10,
#   4,
#   16,
#   8,
#   7,
#   29,
#   77,
#   34,
#   26,
#   10,
#   18,
#   40,
#   21,
#   66],
#  [11, 4, 2, 10, 25, 1, 66, 11, 24, 1, 66, 5, 8, 11, 5, 1, 16, 11],
#  [8, 5, 3, 22, 46, 24, 4, 56, 74, 8],
#  [3, 13, 2],
#  [6, 1, 23, 90, 59],
#  [42, 58, 20],
#  [22, 3, 40],
#  [1, 5],
#  [96, 3, 21, 13, 47, 4, 50, 12, 13, 16, 18],
#  [4, 3, 50, 32],
#  [10, 10, 10, 24, 8, 5, 15, 11, 45, 1, 74, 18, 11, 7, 1, 6, 17, 4, 65],
#  [1, 5, 21, 68, 4],
#  [79, 4, 20, 63, 15],
#  [1, 5, 63, 39, 58, 12, 5, 63, 36],
#  [20, 9, 7, 12, 4, 44, 12, 52, 27, 6, 67, 9, 1, 12, 18],
#  [7, 76, 5, 3, 27, 17, 8, 13, 70, 2, 50, 52, 12, 4],
#  [69, 9, 4],
#  [9, 48, 52, 42, 38, 68],
#  [48, 53, 1, 1, 32, 28],
#  [34, 6, 44],
#  [91, 9, 18, 4, 6],
#  [52, 91, 15, 7, 13, 96, 7, 71, 2],
#  [22, 5, 18, 5],
#  [88, 9, 65, 6, 10, 72, 38],
#  [35, 40, 8, 91, 71, 2, 21],
#  [69, 10, 4, 16, 45, 58, 5, 24, 20, 5, 15, 5],
#  [5, 1, 59, 36, 6, 9, 5, 40, 9, 5, 10, 35, 1, 1, 54, 6, 42, 5, 15, 6, 59],
#  [3, 11, 65, 27, 17, 4, 65],
#  [93, 93],
#  [39, 28, 50, 42, 89, 39, 28, 58],
#  [25, 17, 38, 30],
#  [64, 13, 96, 3, 22, 2, 2, 5, 96, 12, 47, 16, 5, 96, 47, 18],
#  [1],
#  [2, 3, 1, 66],
#  [94, 39, 37, 50, 7, 17],
#  [6, 99, 4, 19, 85, 42],
#  [20, 32, 32, 29, 5, 18, 26, 33, 31, 8, 91, 97, 17, 4, 56],
#  [38, 49, 22, 3],
#  [38],
#  [90, 49, 9, 5],
#  [4, 56, 24, 3, 54, 11, 29],
#  [71, 10, 45],
#  [30, 5, 71, 1, 37, 3, 61, 2, 32, 4, 23, 14, 8, 20],
#  [93, 93, 93, 56],
#  [1, 31, 52, 57, 14, 26],
#  [16, 12, 64, 16, 48, 4, 38],
#  [3,
#   17,
#   36,
#   10,
#   72,
#   72,
#   3,
#   11,
#   76,
#   11,
#   48,
#   13,
#   25,
#   29,
#   51,
#   27,
#   25,
#   10,
#   26,
#   1,
#   33,
#   3,
#   2,
#   13],
#  [65, 8, 91, 7, 97, 13, 18, 5, 15, 4, 68, 50, 2, 21],
#  [1, 62, 77, 22, 3, 85, 44],
#  [23, 49, 60, 3, 7],
#  [37, 7],
#  [83, 78, 16],
#  [6, 10, 16, 11],
#  [46, 4],
#  [1, 97, 14, 5, 60, 57, 3, 17, 15, 21, 11, 74, 48, 29, 5, 9, 11],
#  [6],
#  [62, 25, 2, 27, 55, 20],
#  [11, 8],
#  [75, 18],
#  [9, 1, 35, 8, 6, 11, 9, 11],
#  [74, 21],
#  [4, 1, 27, 73, 2, 18],
#  [37, 8, 18, 3, 27, 27, 17, 4],
#  [3, 67],
#  [34, 25, 8, 11, 8, 7, 4, 30, 75],
#  [88, 9, 83, 65, 34, 1, 59, 36, 3, 34, 1, 26, 3, 37, 61, 35, 30, 56],
#  [3, 52, 49, 39, 79, 12, 7, 1, 22, 2, 52, 49, 39, 28, 18],
#  [43, 41, 59],
#  [3, 12, 2, 2, 3, 1, 62, 7, 3, 45, 1, 3, 8],
#  [35, 15, 26, 47, 19, 73, 2],
#  [35, 9, 2, 35, 8, 21, 68, 2, 64],
#  [30, 45, 1, 1, 8, 5, 7, 30, 29, 5, 1, 45, 65, 9],
#  [37, 58, 61, 4, 61, 1, 33, 3],
#  [],
#  [46, 38],
#  [21],
#  [2, 12, 1, 62, 2, 3],
#  [56, 49, 20, 65, 22, 39, 7, 2, 32, 27, 39, 8, 5, 7, 1, 15, 3, 11, 66, 72],
#  [1, 54, 33, 97, 15, 10, 23, 38],
#  [21, 47, 73, 18, 16, 18, 26],
#  [9, 13, 2, 84, 92, 84],
#  [8, 31],
#  [71, 10, 45],
#  [11, 1, 3, 7, 1, 37, 44, 1, 3, 8, 36, 10, 10, 1, 66, 3],
#  [1, 33, 3, 8, 72],
#  [30, 75, 12, 33, 3, 43, 41],
#  [1, 2, 34, 62, 25, 1, 28, 34, 2, 23, 99, 10, 53, 3, 70, 2, 7, 49, 3, 22, 2],
#  [12, 13, 3, 33, 32, 42, 3, 28, 29, 76, 18],
#  [28, 3, 53],
#  [3, 17, 10, 1, 3],
#  [25, 4, 15, 8, 18, 8, 7, 5, 75],
#  [11, 67, 34],
#  [1, 20, 10, 23, 64, 1, 55, 20, 80, 88, 23, 64, 94, 10],
#  [1,
#   3,
#   3,
#   54,
#   20,
#   4,
#   5,
#   7,
#   30,
#   3,
#   97,
#   14,
#   5,
#   33,
#   45,
#   13,
#   9,
#   57,
#   37,
#   9,
#   4,
#   2,
#   24,
#   1,
#   18,
#   3,
#   44],
#  [10, 4, 2, 11],
#  [14, 25, 4, 97],
#  [1, 33, 32, 3, 29],
#  [7, 42, 47, 18, 18, 16, 18, 26],
#  [14],
#  [1, 33, 16, 3],
#  [20, 63, 3, 94, 55],
#  [42, 47, 13, 16, 47, 18, 2, 21],
#  [11, 21, 6],
#  [23],
#  [23, 40, 22, 39, 75, 12, 5, 64, 26, 5],
#  [64, 1, 28, 46],
#  [1, 23, 1, 62, 8, 24, 11, 9, 8, 1, 18, 12, 5, 1, 20],
#  [3, 44, 53, 63, 22, 7, 20, 75],
#  [48, 5, 9, 25, 12, 74],
#  [59, 7, 85, 45, 6, 16, 87, 23, 4, 71, 9, 3, 33, 68, 6, 4, 71, 1],
#  [3, 22, 13, 52, 67, 3, 15, 13, 18, 3, 22, 74, 15, 5, 1, 4, 15, 13, 3, 3],
#  [56, 4, 76, 5, 15, 1, 58, 48, 7, 1, 3, 22, 3, 48],
#  [93, 24, 1, 70, 2, 5, 90, 1, 31, 26],
#  [47, 71, 2, 12, 4, 26, 71, 31, 2, 12, 4, 47, 22, 2, 73, 84],
#  [49, 9, 3, 2],
#  [5, 25],
#  [15, 3, 31],
#  [5, 15, 43, 41, 8],
#  [31, 2, 2, 1, 54, 4, 15],
#  [51, 59, 40, 36, 11, 65, 46, 32, 56, 72, 63, 72],
#  [56, 4, 26],
#  [],
#  [71, 6, 4, 9],
#  [60, 76, 91, 29, 23, 39, 28, 52, 5, 12, 40],
#  [1, 70, 14, 2, 32, 13],
#  [78, 50, 39, 28, 50, 50, 74],
#  [77],
#  [],
#  [67, 94, 6, 70, 2],
#  [1, 17, 4, 21],
#  [47, 91, 37, 71, 5, 2, 21],
#  [78, 52, 8, 4, 71, 10, 2, 3],
#  [68, 4, 19, 35, 19, 76, 4, 73, 66, 66, 2, 42, 38],
#  [48, 30, 16],
#  [91, 7, 13, 3, 2, 52, 14, 9, 16, 48, 4],
#  [9, 8],
#  [13, 96, 36, 4, 16, 48, 64],
#  [68, 40, 2, 35, 7, 80, 35, 49, 9, 11, 19, 42, 15, 43, 41, 43, 41, 92, 10],
#  [46, 32, 46, 1],
#  [22, 3],
#  [18],
#  [29, 27, 10, 4, 1, 58, 38, 88],
#  [1, 2, 4, 61, 24, 4, 15, 43, 41, 67, 9, 38, 2, 43, 41, 11],
#  [29, 77, 82],
#  [95, 97, 2, 2, 4, 26, 38],
#  [9, 13, 16, 16, 48],
#  [12],
#  [3, 21, 30, 55, 43, 41],
#  [5, 9, 12, 43, 41, 1, 43, 41, 26, 43, 41],
#  [26, 5, 55],
#  [49, 97],
#  [6, 31, 40, 73, 21, 80, 1],
#  [24, 1, 17, 2, 1, 55, 2, 17, 66, 7],
#  [69, 9, 8, 2, 31, 52],
#  [3, 2, 10, 44, 41],
#  [1, 24, 1, 69, 10, 1, 4],
#  [83, 78, 16],
#  [39],
#  [83, 11, 1, 28, 60, 76, 24, 30, 64, 4, 12, 21, 13],
#  [1, 20, 9],
#  [1, 31, 3, 54, 3, 22, 11, 7],
#  [17, 3, 12],
#  [93],
#  [],
#  [12, 40, 3, 4, 56, 65, 88],
#  [93, 93, 53, 22, 3, 70, 2, 38],
#  [46, 1, 33, 99, 2, 52, 61, 24, 39, 22, 33, 40],
#  [12, 17, 3, 39, 28, 85, 16, 47, 26, 71, 87],
#  [1, 50],
#  [29, 4, 7, 1, 55, 6, 4, 1, 54, 6, 55, 10, 55, 20, 23],
#  [1, 3, 5, 15, 7, 80, 7, 13, 7, 51, 5],
#  [20, 16, 1, 79, 70, 66],
#  [75, 4, 7, 44, 36, 5, 9, 5, 63, 33, 1],
#  [6, 50, 11, 9, 3, 17, 2, 8],
#  [65, 2],
#  [3, 21, 13, 47, 12, 13, 16, 21, 18, 52],
#  [83, 78, 16, 46],
#  [46, 1, 62, 18, 5, 2],
#  [1, 66, 7, 9, 11, 49, 80, 3, 1, 66, 43, 41],
#  [98, 20, 18, 5, 2, 14, 48, 67],
#  [45, 22, 3, 75, 2, 13],
#  [38, 79, 78, 42, 19, 84],
#  [67, 22, 99, 10, 5],
#  [40, 9, 13, 2, 13, 42, 26, 16, 48],
#  [49, 14, 3],
#  [1,
#   20,
#   5,
#   13,
#   5,
#   33,
#   61,
#   43,
#   41,
#   2,
#   11,
#   7,
#   43,
#   41,
#   58,
#   23,
#   5,
#   7,
#   32,
#   3,
#   5,
#   3,
#   22,
#   2],
#  [70, 19, 31, 70, 19, 35, 5, 76, 2],
#  [76, 4, 98, 15, 10, 1, 6, 56],
#  [46, 30, 44, 2, 8, 55],
#  [66, 3, 66, 6],
#  [53],
#  [93, 28, 1, 44, 45],
#  [3, 87, 3, 80, 25, 12],
#  [67, 86, 6, 8, 4],
#  [4, 22, 10, 80, 3, 3, 29, 51, 40],
#  [82],
#  [3, 1, 2, 5],
#  [3, 13, 2],
#  [34, 39, 61, 38, 12, 63],
#  [47, 13, 47, 71, 76, 2, 40, 36, 5, 47, 12],
#  [53, 2, 3],
#  [18, 34, 3, 70, 5, 1, 57, 80, 34, 3, 70, 19],
#  [1, 14, 28, 3, 68, 4],
#  [83, 11, 26, 1, 34, 3, 70, 39, 87, 26, 1, 36, 11],
#  [12, 19, 9, 16, 21, 51, 42, 47, 94, 52],
#  [83, 8, 78, 16],
#  [53, 15, 43, 41],
#  [22, 3, 47, 21, 28, 1, 16, 21],
#  [58, 45],
#  [1, 33, 50, 12, 14, 18, 83, 1, 23],
#  [15, 9, 25, 9, 14],
#  [],
#  [1, 17],
#  [36, 5, 9, 6, 26, 36, 9, 2, 6, 9, 34, 6, 6, 34, 6, 6, 85],
#  [45, 28, 60, 52],
#  [36],
#  [1, 48, 4, 2],
#  [8, 40, 6, 17, 5, 2, 37, 16, 84, 64],
#  [38, 8, 58, 19, 27, 29, 77, 28, 27, 11, 26],
#  [26, 5, 11],
#  [3, 54, 21, 23, 22, 3, 2, 7, 7, 55, 20, 1, 79, 13, 4, 8, 79],
#  [5],
#  [13, 80, 10, 19, 42, 25, 92],
#  [29, 5, 85, 67, 34, 3, 28, 44, 7, 70, 2, 5, 4],
#  [30, 30],
#  [46, 13],
#  [38, 64],
#  [3, 22, 5, 4, 26, 4, 73, 2, 38],
#  [38, 12],
#  [12, 92, 26, 19, 60, 36, 10, 26, 84, 42, 73],
#  [13, 17, 44, 12, 13, 9],
#  [20, 9, 18, 76, 5, 34, 6, 70, 2, 89, 2, 11, 47, 24, 79, 2, 54, 72, 18],
#  [5, 9, 8, 24, 8, 37, 1, 16, 3, 21],
#  [24, 18, 14, 32],
#  [1, 60, 2, 31],
#  [50, 31],
#  [3, 18],
#  [13, 96, 38, 59, 4, 18, 40, 9, 91, 2, 3, 16],
#  [1, 42, 24, 27, 89],
#  [35, 15, 71, 2, 21, 96, 92],
#  [49, 9, 4, 55, 3],
#  [3, 33, 13, 5, 12, 7, 86, 6],
#  [20, 4],
#  [13, 12, 1, 16],
#  [53, 88, 9, 23, 38],
#  [75, 18],
#  [78, 32],
#  [25,
#   3,
#   8,
#   4,
#   40,
#   9,
#   14,
#   59,
#   7,
#   20,
#   3,
#   54,
#   20,
#   39,
#   3,
#   1,
#   23,
#   11,
#   66,
#   17,
#   4,
#   65],
#  [56, 11, 66, 49, 20, 65, 1, 3, 58, 18, 4, 1, 15, 3, 7, 68, 3, 4, 48, 5],
#  [32, 12, 4, 86, 3, 43],
#  [26, 11, 37, 51, 7, 14, 54, 53, 2, 27],
#  [15, 65, 11],
#  [1, 62, 8, 90, 3, 48, 16, 10],
#  [48, 73, 84],
#  [4, 45, 3, 5, 2, 2, 13, 26, 14, 3, 22],
#  [24, 62, 75, 2, 53, 2, 27, 22, 60, 67, 14],
#  [42, 29, 37, 2, 52, 4],
#  [40, 25, 8, 40, 79, 63, 52, 57, 32, 44, 8],
#  [57, 67],
#  [1,
#   54,
#   24,
#   3,
#   79,
#   2,
#   31,
#   21,
#   1,
#   37,
#   58,
#   11,
#   24,
#   1,
#   2,
#   9,
#   2,
#   12,
#   10,
#   2,
#   60,
#   2],
#  [83, 20, 23, 21],
#  [43, 41],
#  [46, 10, 1, 1, 86, 11, 3, 11, 5, 63],
#  [3,
#   31,
#   2,
#   20,
#   1,
#   17,
#   3,
#   13,
#   3,
#   10,
#   12,
#   4,
#   1,
#   24,
#   5,
#   15,
#   20,
#   18,
#   13,
#   76,
#   5,
#   3,
#   3,
#   11],
#  [44, 12, 55],
#  [34, 1, 31, 48, 3, 20, 7, 2, 4],
#  [46, 97, 4, 4, 15, 7, 86, 4, 15, 3, 85, 79, 2, 37, 23, 20, 3, 54],
#  [17, 4, 29, 5, 8, 26, 4, 38, 4, 2, 32, 4],
#  [9, 55],
#  [3, 22, 25, 8],
#  [1, 54, 20, 11, 20],
#  [3, 12, 5, 3, 22, 49, 22, 3],
#  [6, 91, 74, 1, 95, 92, 63, 6, 92, 23, 23, 25, 58, 76, 35],
#  [10, 30, 8],
#  [42],
#  [1, 66, 3, 23, 1, 28, 14],
#  [39, 22, 2, 3, 20, 3, 4, 16, 64],
#  [1, 3, 3, 54, 3, 10, 68, 3, 13, 1, 79, 3, 1, 70, 3, 1, 3],
#  [16, 6, 29, 36, 11, 20, 84, 10, 19, 93],
#  [53, 22, 3, 15],
#  [23, 3, 28, 37, 50, 2, 13, 26, 11, 66, 1, 13, 46, 7, 4, 56, 65, 1, 3, 23],
#  [66, 14, 33, 3, 36, 1, 62, 75, 2, 13, 36, 11],
#  [6, 27, 57],
#  [82, 42, 11, 19, 57, 17, 82, 1, 29, 77, 11, 21, 11],
#  [27, 3, 54, 11],
#  [28, 3, 5],
#  [12, 13, 16],
#  [1, 8, 42],
#  [3, 17, 26, 4, 19, 2],
#  [30, 15, 36, 3, 80, 40, 27, 53, 3, 70, 7, 48, 21, 18, 78, 27, 5],
#  [42, 10, 8, 1],
#  [91, 96, 2, 87, 26, 5, 18],
#  [9, 6, 81, 4, 6, 66, 9, 8, 15, 10, 10],
#  [23, 57],
#  [46, 38, 79, 2, 36, 53, 3],
#  [39, 2, 3, 13, 92, 2, 91, 15, 4, 16, 21, 26, 92, 12, 47],
#  [11, 59, 25, 2, 17, 27, 3, 70, 74, 65],
#  [23, 3, 22, 25, 13, 97, 5],
#  [99, 6, 17, 4, 7, 37, 70, 2, 15, 63],
#  [1, 78, 28, 50, 28, 39, 28, 50, 91],
#  [28, 3],
#  [],
#  [30, 8, 4, 16, 10, 29],
#  [12, 35, 2, 4, 73, 2, 73, 19],
#  [3, 17, 2, 4, 16, 5],
#  [13, 12, 1, 16],
#  [3, 85, 29],
#  [1, 3, 72, 4, 7, 3, 72, 11, 72, 72, 5, 91, 32],
#  [1, 62, 49, 22, 3],
#  [17, 4, 65],
#  [3, 17, 16, 21],
#  [33, 27, 59, 18, 40, 7, 3],
#  [30, 75, 52, 2],
#  [38, 33, 48, 21, 18, 8],
#  [34, 6, 77, 46, 82, 30, 25],
#  [15, 69, 17],
#  [32, 67, 1, 33, 60],
#  [],
#  [97, 89, 31],
#  [36, 48, 47, 19, 51],
#  [53, 1, 2, 9, 2, 86, 6, 15, 40],
#  [46],
#  [31, 4, 26, 70, 10, 2, 60, 3],
#  [2, 12, 6, 33, 32, 44, 2, 36, 5, 7, 2, 32, 68, 31, 73, 84, 2],
#  [61, 4, 68, 2, 51, 35, 34, 81, 57, 6, 10, 5, 10],
#  [1, 17],
#  [88, 14, 59, 19, 44, 24, 39, 19, 63, 97, 6],
#  [1, 7, 51, 2, 57, 69, 17, 2, 40],
#  [65, 1, 54, 61, 24, 1, 17, 15, 7, 2, 23, 1, 2, 7],
#  [69, 55, 25, 9, 55, 55, 51, 54, 69, 58, 10, 35, 82],
#  [12, 11],
#  [1, 60, 89, 44, 60, 52, 35],
#  [67, 32, 67, 32, 40, 15, 23, 28],
#  [39, 58, 43, 41],
#  [56, 24, 6, 8],
#  [9, 8, 72, 72],
#  [83, 38, 17, 58, 2, 27, 32, 8],
#  [34, 3, 28, 37, 26, 26, 4],
#  [56, 2, 30, 7, 18, 5, 12],
#  [49, 14, 97, 2, 31, 2, 5, 15, 4],
#  [1, 81, 20, 33, 11, 10, 25, 19],
#  [19, 8, 35, 42, 37, 47, 19, 26, 29, 73, 74, 2],
#  [36, 22, 2, 4, 4, 34, 13, 16, 2, 13],
#  [94, 55, 20],
#  [6],
#  [20, 59, 4, 1, 3, 68, 20, 2, 10],
#  [58, 14, 12, 46],
#  [19, 40, 29, 13, 50, 2, 19, 84, 73, 84, 2],
#  [10, 89, 23],
#  [3, 22, 25, 20, 15, 65, 17, 74, 36, 15, 2],
#  [45, 63, 77, 21],
#  [53, 33, 39, 27, 8, 5],
#  [1, 6, 4, 61],
#  [79, 2, 78, 3, 54, 45, 30, 52],
#  [1, 27, 5, 69, 9, 4, 69, 15, 4, 2, 65],
#  [76, 8, 4],
#  [32, 18],
#  [39, 17, 5, 7, 18, 5, 7, 1, 8, 17, 4, 56, 15],
#  [29, 2, 50, 53, 80, 6],
#  [27, 3, 34, 1, 53, 3, 94, 17, 2, 34, 14, 9],
#  [13, 12, 1, 16],
#  [38, 1, 33, 68, 2, 13],
#  [3, 17, 26, 4, 19, 2],
#  [7, 7],
#  [30, 38, 83, 1, 24, 72, 62, 2, 80, 63, 83, 22, 3, 18],
#  [27, 3, 54, 34, 8, 1, 95],
#  [1, 3],
#  [6, 58, 20],
#  [99, 5],
#  [60, 2, 24, 68, 72, 60, 2, 24, 68, 72, 1, 60, 2, 6, 24, 28, 68, 11, 72, 2, 6],
#  [3, 33, 32, 8, 5, 15, 20],
#  [14, 2, 97, 14, 67, 61, 47, 34, 3, 79, 2, 54],
#  [7, 22, 16],
#  [5, 67, 4, 8, 5, 67, 9, 8, 5, 67, 9, 4, 18, 5, 67, 22],
#  [57, 49],
#  [83, 10, 75, 77, 60],
#  [14, 12],
#  [39, 28, 51, 5, 15, 5],
#  [57],
#  [32, 8, 4, 34, 3, 85, 79, 2],
#  [40, 9, 43, 41],
#  [17, 4, 56],
#  [6, 11],
#  [86],
#  [3],
#  [31, 35, 47, 21, 92, 2, 40, 36, 2, 13, 37, 19, 52, 68, 84],
#  [7, 3, 17, 2, 80, 10, 2, 3, 55, 1, 3, 27, 3, 70, 7, 78, 27, 5],
#  [58, 43, 41, 1, 44],
#  [1, 94, 1, 37],
#  [2, 7, 52, 34, 58, 26],
#  [81, 6, 1, 85, 30, 75, 42, 21],
#  [30, 25],
#  [13, 16, 1, 59, 29, 6, 12, 6, 2, 60, 77, 30, 23, 88],
#  [53, 9, 40, 3, 15],
#  [42],
#  [9, 75, 42],
#  [30, 1, 62, 7, 72, 4, 1, 66, 71, 10, 30, 1, 11, 21, 71, 2, 76],
#  [1, 2, 2, 42, 10, 2, 11, 8],
#  [17, 3],
#  [59, 4, 7, 59, 4, 25, 6, 81, 88, 24, 6],
#  [10, 29, 8, 6, 81, 16, 6, 1, 26, 99, 10, 65, 6, 81, 1, 62, 61],
#  [66, 24, 62, 1, 26],
#  [48, 16, 72, 67, 9, 12, 3],
#  [59, 5],
#  [83, 2, 6, 28, 12, 11, 51, 19, 89],
#  [11, 8, 3, 22, 4, 37],
#  [33, 88, 7, 2, 3, 27, 3, 17, 4],
#  [55, 17, 2, 68, 8, 11, 2, 31, 14, 4],
#  [56, 56, 1, 55],
#  [3, 76, 26, 85],
#  [3, 8, 3, 28, 86, 49, 11, 9],
#  [2, 77],
#  [93, 6, 94, 26, 92, 2],
#  [49, 81, 2],
#  [83, 78, 16],
#  [53, 9, 9, 20, 3, 76],
#  [4, 9, 5, 27, 2, 32, 24, 56, 33, 32, 8],
#  [1, 2, 7, 23, 23, 1, 3, 8, 63],
#  [1, 98, 1, 28, 31, 12, 4, 20, 36, 8, 83],
#  [23, 45, 27, 3],
#  [1],
#  [2, 7, 5, 89, 36, 50, 19, 48, 92, 36, 5, 52],
#  [42, 47, 13, 16, 47, 18, 2, 21],
#  [15, 51, 5, 19, 8, 5, 76, 51, 52, 15, 64, 69, 34, 14, 9, 76, 11],
#  [14,
#   37,
#   55,
#   20,
#   5,
#   20,
#   51,
#   3,
#   7,
#   70,
#   9,
#   12,
#   10,
#   2,
#   60,
#   9,
#   5,
#   65,
#   72,
#   45,
#   4,
#   9,
#   2,
#   10,
#   7],
#  [],
#  [5, 34, 5, 4, 37, 68, 13, 7, 5, 33, 32, 2, 3],
#  [69, 80, 64, 90, 1, 54],
#  [45, 1, 17, 2, 1, 99, 3],
#  [40, 9, 5, 2, 6, 6, 17, 16],
#  [57, 3, 10, 1, 33, 16, 44, 26, 30, 75, 2, 31, 11, 9],
#  [3, 17, 4, 26, 4, 2, 16, 91, 18],
#  [94, 1, 28, 13, 10, 74, 36, 10, 7, 1, 17, 12, 15, 16, 10],
#  [9, 14, 68, 10, 5],
#  [51, 5, 36, 14],
#  [20, 9],
#  [17, 18],
#  [5,
#   9,
#   7,
#   1,
#   62,
#   85,
#   51,
#   22,
#   5,
#   23,
#   32,
#   14,
#   26,
#   1,
#   17,
#   2,
#   1,
#   62,
#   57,
#   9,
#   5,
#   26,
#   10,
#   16,
#   40,
#   9,
#   7,
#   36,
#   5,
#   32,
#   6,
#   81],
#  [58, 14, 14, 2, 3, 51],
#  [15, 28, 30, 25, 23, 46, 82, 6, 39, 50, 1, 6, 18, 24, 69, 6, 33, 88],
#  [11, 2, 4],
#  [49, 9, 2, 26, 37],
#  [6, 10],
#  [2, 16],
#  [38, 69, 9],
#  [3, 45, 1, 2, 97, 3, 52, 2, 4],
#  [6, 94, 31, 8, 37, 26, 7, 37, 94, 7, 14, 37, 94, 92],
#  [2, 8, 15, 51, 10, 8, 35],
#  [57, 38, 74, 2, 10],
#  [12, 52, 12, 10, 1],
#  [5, 96, 48, 64, 29, 73, 2, 38, 31, 21],
#  [1, 36, 3, 21],
#  [6, 54, 10, 90, 15, 76, 9, 82, 6, 50, 74, 57, 51, 8, 91],
#  [1, 33, 32, 67, 3, 14],
#  [27, 51, 33, 12, 63, 15, 56],
#  [37,
#   58,
#   44,
#   17,
#   2,
#   32,
#   52,
#   15,
#   5,
#   1,
#   5,
#   87,
#   29,
#   1,
#   29,
#   2,
#   31,
#   44,
#   7,
#   57,
#   14,
#   59,
#   8],
#  [46, 67, 32, 4, 47, 80],
#  [55, 44],
#  [69, 50, 63],
#  [1, 2, 97, 56, 15, 3, 1, 17, 2, 21, 68, 45, 3, 31, 4],
#  [6, 22, 2, 5, 96, 8, 5, 12, 3, 68, 84, 2],
#  [9, 67, 4, 25, 40, 17, 4, 7, 51, 5, 8, 13],
#  [76, 10, 5],
#  [27, 3, 20, 8, 80, 17, 15, 36],
#  [3, 17, 48],
#  [94, 20],
#  [45, 3, 31, 2, 5],
#  [83, 1, 98, 40, 7, 62, 21, 81, 6],
#  [23, 3],
#  [15, 36, 15, 11],
#  [66, 3, 17, 51, 40],
#  [6, 17],
#  [16, 10, 45, 3, 9, 22, 11, 9, 44, 7, 1, 25],
#  [19, 19, 48, 21, 42, 16],
#  [39, 22, 29, 6, 85, 1, 40, 24, 1, 1, 62, 37, 57, 39, 18],
#  [35, 9, 85, 16, 21],
#  [24, 39, 6, 6, 24, 39, 52, 23, 88, 25, 75, 52, 16, 82],
#  [3, 7, 13, 7, 8],
#  [35, 4, 7, 4, 73, 2],
#  [30, 58, 18, 42, 82, 1, 33, 50, 63],
#  [83, 78, 16],
#  [1, 5, 21, 68, 4],
#  [1, 54, 23, 12, 39, 8, 5, 15, 2, 31],
#  [25, 36, 40],
#  [6, 37, 11, 29, 85, 44, 42, 5],
#  [31, 3, 22, 25, 13, 52, 15, 40, 8, 4],
#  [1, 32, 67, 36, 8, 43, 41, 58],
#  [37, 7],
#  [12, 44, 5],
#  [98, 3, 50, 99, 13, 25, 3, 70, 2, 36, 69, 57, 2, 60],
#  [61, 14, 59, 2, 86, 3, 7, 3, 1, 58, 2, 7, 4, 10],
#  [11, 1, 27, 3, 37, 58, 13, 7, 2, 68, 3, 40, 71, 3, 64],
#  [20, 31, 5],
#  [13, 80, 10, 19, 42, 25, 92],
#  [1, 39, 19, 25, 3, 22, 49, 1, 3],
#  [],
#  [3, 17, 48, 16, 21],
#  [94, 23, 14, 55, 15],
#  [95, 59, 2, 32, 24, 14, 85, 8],
#  [14, 14, 18, 61, 15, 5, 63, 14, 11, 24, 14, 4, 50],
#  [80, 4, 56, 36, 4, 37, 73, 87, 7, 2, 5, 96],
#  [47, 16, 31, 4, 37, 71, 2],
#  [4, 65],
#  [40, 9, 3, 13, 83, 25, 8, 24, 54, 20, 3, 22, 17, 4],
#  [51, 42, 35],
#  [6, 29, 61, 37, 55],
#  [1, 70, 2, 1, 7, 1],
#  [67, 74, 6, 8, 5, 15],
#  [10, 37],
#  [3, 21, 13, 47, 12, 13, 16, 21, 18, 52],
#  [3, 10, 7, 51, 13, 8, 60, 34, 3],
#  [46, 1, 6, 1, 11],
#  [4, 59, 43, 41],
#  [35, 15, 88, 71, 2, 21, 96],
#  [9, 29, 43, 63, 41, 62, 25, 11, 6, 98, 1, 6],
#  [47, 12, 42, 35, 96, 37, 73, 2, 31, 7, 99, 35],
#  [3, 17, 4, 26, 35, 16, 47, 18, 19, 84, 18],
#  [93, 78, 32, 67, 42],
#  [1, 61],
#  [24, 69, 39],
#  [3, 37],
#  [1, 62, 65, 1, 62, 25],
#  [1, 98, 31, 52, 15, 23],
#  [43, 41],
#  [23, 4, 20, 36, 5, 67, 23, 28],
#  [35, 15, 47, 19, 91, 73, 2],
#  [1, 35, 46],
#  [6, 76, 18, 5, 19, 19, 92, 52],
#  [11, 1, 3, 53],
#  [69, 15, 24, 5, 17, 2, 14, 7, 14, 44],
#  [22, 3, 26],
#  [57, 3, 25],
#  [6, 6, 19, 18, 46, 97, 15],
#  [56, 11, 69, 10, 2, 10, 1, 3],
#  [18, 5, 23, 73],
#  [12, 71, 36, 84, 38],
#  [42, 8, 79, 18, 35, 99, 35, 73, 2, 12, 26, 12, 19],
#  [17, 4, 56],
#  [7],
#  [13],
#  [3, 58],
#  [83, 1, 43, 41, 24, 69, 25, 32],
#  [12, 3, 17, 3, 5],
#  [6, 17, 4, 6, 81, 23, 16, 2, 52, 92, 84],
#  [61, 6, 4, 37, 4, 6, 8, 23],
#  [2, 40, 29, 3, 50, 2, 2, 84, 73, 84, 2],
#  [3, 23, 45, 39, 7, 39, 31, 5, 15, 13, 3, 22, 56, 3, 39, 22, 2, 40, 9, 5, 1],
#  [33],
#  [56, 11, 17, 4, 65],
#  [27, 3, 70, 71, 7, 4, 12, 64, 16, 26, 92, 12],
#  [1,
#   17,
#   8,
#   12,
#   5,
#   7,
#   2,
#   4,
#   43,
#   41,
#   1,
#   14,
#   32,
#   15,
#   10,
#   2,
#   80,
#   3,
#   29,
#   2,
#   7,
#   1,
#   44,
#   1,
#   62,
#   8,
#   4,
#   7,
#   32,
#   2,
#   5,
#   40,
#   11,
#   15,
#   28,
#   3],
#  [39, 2, 3, 91, 15, 16, 26, 92, 12],
#  [19, 35, 15, 71, 2, 21, 96, 73, 26, 84],
#  [1, 6, 6, 49, 6, 81, 19, 10, 6, 6],
#  [68, 10, 4, 80, 30, 45, 7, 49],
#  [91, 12, 7],
#  [16, 48, 13, 13, 42, 26],
#  [93, 93, 45, 22, 3, 75],
#  [8, 5, 2, 43, 41, 15, 20, 59, 7, 9, 2, 26, 1, 98, 1, 98],
#  [11, 23, 1, 1, 37, 1],
#  [1, 62, 8, 5, 10, 21, 1, 33, 16, 3, 29],
#  [12, 5, 15, 83, 86, 3],
#  [35, 15, 71, 2, 21, 96, 92],
#  [6, 6, 19, 50],
#  [1, 62, 1, 70, 2, 52, 13],
#  [38, 90, 34, 3, 20, 14, 5, 90],
#  [15, 50, 19, 6, 15],
#  [84, 5, 14, 7, 1, 25, 14],
#  [26, 8, 66, 8, 5, 71, 37, 71, 2, 7, 86, 3],
#  [75, 2, 97, 13, 52],
#  [62, 18, 43, 41, 32, 67, 8, 57, 39, 50, 2, 92, 10, 2, 77],
#  [14, 9, 57],
#  [69, 37, 9],
#  [8, 21, 75, 17, 8],
#  [13, 9, 4],
#  [83, 1, 1, 28, 31, 4, 15, 11, 26, 78, 71, 3],
#  [6, 52, 53, 63, 5, 9, 29, 1, 79, 2, 52],
#  [4],
#  [35, 4, 15, 48, 26, 4, 16],
#  [24, 1, 7, 7, 37, 1, 18, 24, 1, 13, 9, 20, 14, 98],
#  [13, 12, 1, 16],
#  [39, 79, 7, 2, 12, 28, 1, 3, 1, 79, 13, 7, 81],
#  [53, 27, 6, 70, 12, 49, 80, 47, 71, 4, 36, 16, 47, 21, 18, 2, 52],
#  [62, 8, 4, 23, 34, 6, 16, 62, 29, 77, 2, 32],
#  [61, 75, 56, 38, 24, 85, 79, 2],
#  [78, 71, 3, 45, 1],
#  [61, 4, 65, 30, 37, 70, 2, 44, 7, 97, 4],
#  [36, 8, 4, 65, 3, 33, 13, 8, 40, 43, 41],
#  [6, 9, 14, 3, 26, 16, 21, 96],
#  [22, 3, 8, 3, 79, 2, 86],
#  [4, 34, 6, 54, 8, 73, 2],
#  [6, 17, 4, 9, 19, 36, 6, 52, 81, 35, 23, 16, 18],
#  [6, 17, 4, 9, 19, 36, 6, 52, 81, 35, 23, 16, 18],
#  [3, 17, 25, 5, 3, 17, 12, 2, 13],
#  [86,
#   1,
#   3,
#   4,
#   4,
#   2,
#   3,
#   2,
#   1,
#   59,
#   3,
#   74,
#   24,
#   4,
#   9,
#   25,
#   31,
#   52,
#   19,
#   3,
#   79,
#   2,
#   60,
#   77,
#   3,
#   79,
#   2,
#   7,
#   34,
#   3,
#   79,
#   2],
#  [1, 66, 2, 1, 15, 53, 9, 13],
#  [39, 50],
#  [6, 54, 49, 2, 12, 4, 8, 11],
#  [],
#  [1, 55, 2, 24, 62, 25, 2, 1, 94, 54],
#  [6, 55, 95],
#  [3],
#  [49, 95, 5, 63, 15],
#  [27, 3],
#  [1, 62, 53, 22, 3, 80, 10],
#  [3],
#  [46, 1, 24, 30, 23, 1, 6, 1, 95, 42, 10, 74],
#  [17, 7, 32, 2, 29, 43, 41],
#  [32, 20, 6, 94, 17, 6, 70, 20, 6, 85, 17, 2, 32, 6, 22, 88],
#  [3, 22, 4, 56, 37, 8],
#  [30, 2, 14, 1, 37, 11, 98, 10, 64, 4, 40, 40, 10, 8, 8, 59],
#  [14, 52, 57],
#  [13, 47, 9, 2, 32, 71, 5, 2, 2, 31, 7],
#  [22, 7, 1, 17, 12, 1, 7],
#  [49, 9, 14, 2, 3, 7],
#  [1, 34, 13, 1, 2, 99, 3, 1, 66, 3],
#  [18, 40, 7, 14],
#  [51, 7, 17, 5],
#  [44, 83, 80, 5, 92],
#  [51, 5, 48, 7, 5, 36, 26, 71, 2],
#  [1, 1, 17, 14, 95, 3, 39],
#  [22, 8],
#  [21, 16, 48, 2, 2, 84, 16],
#  [11,
#   66,
#   49,
#   60,
#   14,
#   3,
#   23,
#   2,
#   12,
#   1,
#   58,
#   13,
#   18,
#   7,
#   59,
#   2,
#   86,
#   24,
#   59,
#   3,
#   1,
#   3],
#  [1, 62, 83, 14, 3],
#  [1, 30, 23, 1, 51, 88, 1, 59, 2, 52, 1, 59, 51, 7, 21, 30, 25],
#  [46, 82, 24, 25, 10, 85, 21],
#  [16, 10, 90, 1, 62, 12, 13, 16],
#  [1, 34, 39, 31, 34, 28, 8],
#  [59, 80, 2, 68, 3, 4, 88, 17, 4],
#  [45, 86, 11, 2, 22, 54, 20, 2, 11],
#  [3, 13, 45, 3, 12, 29],
#  [94, 2, 46, 61, 11],
#  [45, 6, 86, 14, 57],
#  [18, 2, 28, 3, 68, 10],
#  [14, 32, 1, 17, 21, 33],
#  [95, 2, 88, 24, 85, 77],
#  [1, 11, 21, 1, 29],
#  [93, 68, 43, 41],
#  [24, 30, 18, 4, 7, 1, 15, 30, 18, 4],
#  [93, 1, 33, 11],
#  [51, 17, 2, 60],
#  [3, 81, 4, 19, 13, 71, 19, 2, 71],
#  [30, 83, 1, 19, 27, 40, 6, 28, 75, 46],
#  [14, 7, 1, 3, 2, 7, 3, 50],
#  [23, 27, 3, 17],
#  [53, 63, 3, 17, 14, 79, 2, 54, 45, 1, 32],
#  [16, 48, 4, 13, 42, 26],
#  [57, 82],
#  [45],
#  [93, 93, 22, 3, 8],
#  [16, 48, 13, 42, 26],
#  [44, 12, 7, 55, 4, 21, 1, 24, 29, 61, 25, 15],
#  [38, 39, 14, 51, 23, 17, 34, 57, 91, 2, 87, 8],
#  [14, 2, 15, 64, 7, 22],
#  [49, 80, 8, 36, 12, 37, 73, 87, 13, 7, 2, 8, 5],
#  [7, 4, 23, 25, 71, 52, 15, 5, 12],
#  [1, 11, 2, 7, 1, 2, 27, 12, 4, 1, 34, 3, 22, 15, 27, 4, 18, 9, 74, 10, 5],
#  [1, 2, 86, 3, 49, 5],
#  [35, 9, 2, 35, 8, 21, 68, 50, 2, 64],
#  [1, 5, 18, 53, 22, 39, 75, 12, 13, 47, 39, 79, 2, 7, 91],
#  [8, 35],
#  [9, 20, 53, 63, 3, 70, 10, 2, 60],
#  [54],
#  [46, 82],
#  [91, 45, 9, 8, 14, 24, 14, 45, 14, 56],
#  [2, 31, 48, 13],
#  [7, 12, 13],
#  [83, 1, 21, 57, 35, 82, 23, 24, 64, 42, 74, 17, 4, 19, 8],
#  [66, 4, 4, 34, 39, 2, 66, 57, 32, 24, 57],
#  [69],
#  [11, 9, 7, 38, 9, 5, 9, 28, 3, 92, 2, 40, 2, 5],
#  [],
#  [6, 6, 97, 63],
#  [39, 22, 2, 6, 20, 3, 17, 4, 16, 48, 64],
#  [29, 2, 50, 53, 80, 6],
#  [27, 3, 97, 5, 9],
#  [22, 3, 40],
#  [26, 85, 28, 3, 7, 34, 95, 28, 43, 41, 12, 10],
#  [1, 62, 25, 80, 1, 54, 64, 80],
#  [53,
#   27,
#   6,
#   70,
#   45,
#   1,
#   60,
#   87,
#   4,
#   72,
#   4,
#   15,
#   11,
#   12,
#   3,
#   53,
#   1,
#   33,
#   24,
#   64,
#   2,
#   11,
#   15,
#   11,
#   32,
#   20,
#   7,
#   86,
#   38,
#   74,
#   28,
#   3,
#   20,
#   94,
#   16,
#   10,
#   1,
#   33,
#   1,
#   60],
#  [22, 3, 2, 50, 12],
#  [14, 19, 72, 19, 52, 9, 20, 46],
#  [82, 69, 19, 50, 88, 23, 82, 1, 6],
#  [87, 21, 57],
#  [1, 23, 82],
#  [53, 9, 13],
#  [6, 68],
#  [38, 1, 4, 59, 19, 36, 10, 6, 24, 6, 63],
#  [46, 1, 2],
#  [94,
#   3,
#   54,
#   40,
#   9,
#   5,
#   63,
#   95,
#   55,
#   20,
#   23,
#   1,
#   15,
#   53,
#   95,
#   7,
#   5,
#   65,
#   26,
#   34,
#   5,
#   65,
#   23,
#   20,
#   39,
#   28,
#   32,
#   61],
#  [3, 28, 36, 64, 43, 41],
#  [1, 79, 7],
#  [34, 69, 69, 33, 31, 8, 69, 17, 7],
#  [79, 2, 32, 8, 76, 2, 48],
#  [19, 96, 81, 16, 21, 13],
#  [29, 5, 63, 53, 5, 3, 9, 44],
#  [53, 1, 37],
#  [32, 29, 8, 43, 41],
#  [30, 8, 21, 1, 33, 16, 3, 43, 41],
#  [1, 3, 3, 54, 13, 51, 1, 28, 80, 1, 45, 39, 33, 32],
#  [5, 74, 34, 16, 76, 16, 12, 64, 58, 12],
#  [87, 2, 48, 11, 9],
#  [15],
#  [5, 63, 39, 17, 2, 31, 44, 29, 65, 59, 5, 56, 5, 1, 31, 77, 29],
#  [44, 2, 60, 57, 60, 82, 24, 1],
#  [5, 9, 5, 9, 66, 5, 9, 4, 6],
#  [1, 1, 98, 17],
#  [74, 2],
#  [30, 8, 28, 3, 25, 18, 14, 2, 14, 46, 21],
#  [25, 4, 9, 29, 7, 9, 37, 10, 7, 8, 29, 5, 49, 17, 3],
#  [57, 42, 10, 29, 84, 35, 34, 1, 57, 1, 50, 31, 11, 57, 60, 87, 89],
#  [33, 27, 12, 52],
#  ...]

# %%
max_len = 50
sequences = sequence.pad_sequences(text_tokenized,maxlen=max_len)

# %%
sequences
# Out:
# array([[ 0,  0,  0, ..., 89, 67, 58],
#        [ 0,  0,  0, ...,  0, 46,  6],
#        [ 0,  0,  0, ...,  2,  2, 73],
#        ...,
#        [ 0,  0,  0, ..., 12, 20, 23],
#        [ 0,  0,  0, ...,  2, 12, 47],
#        [ 0,  0,  0, ..., 61,  2, 61]], dtype=int32)

# %%
# Build model

# %%
model = Sequential()
model.add(Embedding(max_words, 20, input_length=max_len))
model.add(LSTM(64))
model.add(Dense(1, activation="sigmoid"))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(sequences,Y,batch_size=128,epochs=10,
          validation_split=0.2)
# Out:
# Train on 4457 samples, validate on 1115 samples
# Epoch 1/10
# 4457/4457 [==============================] - 2s 560us/step - loss: 0.5013 - acc: 0.8503 - val_loss: 0.3872 - val_acc: 0.8700
# Epoch 2/10
# 4457/4457 [==============================] - 2s 362us/step - loss: 0.3598 - acc: 0.8649 - val_loss: 0.3011 - val_acc: 0.8700
# Epoch 3/10
# 4457/4457 [==============================] - 2s 356us/step - loss: 0.2269 - acc: 0.9100 - val_loss: 0.1555 - val_acc: 0.9525
# Epoch 4/10
# 4457/4457 [==============================] - 2s 354us/step - loss: 0.1369 - acc: 0.9560 - val_loss: 0.1162 - val_acc: 0.9570
# Epoch 5/10
# 4457/4457 [==============================] - 2s 353us/step - loss: 0.1140 - acc: 0.9614 - val_loss: 0.1067 - val_acc: 0.9605
# Epoch 6/10
# 4457/4457 [==============================] - 2s 356us/step - loss: 0.1062 - acc: 0.9628 - val_loss: 0.1026 - val_acc: 0.9587
# Epoch 7/10
# 4457/4457 [==============================] - 2s 384us/step - loss: 0.0995 - acc: 0.9663 - val_loss: 0.0984 - val_acc: 0.9614
# Epoch 8/10
# 4457/4457 [==============================] - 2s 422us/step - loss: 0.1005 - acc: 0.9663 - val_loss: 0.0987 - val_acc: 0.9632
# Epoch 9/10
# 4457/4457 [==============================] - 2s 460us/step - loss: 0.0934 - acc: 0.9684 - val_loss: 0.0999 - val_acc: 0.9605
# Epoch 10/10
# 4457/4457 [==============================] - 2s 401us/step - loss: 0.0890 - acc: 0.9695 - val_loss: 0.1011 - val_acc: 0.9641

# %%
# Predict on new test data

# %%
inp_test_seq = "WINNER! U win a 500 prize reward & free entry to FA cup final tickets! Text FA to 34212 to receive award"

# %%
test_sequences = mytokenizer.texts_to_sequences(np.array([inp_test_seq]))
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

# %%
model.predict(test_sequences_matrix)
# Out:
# array([[0.97663873]], dtype=float32)
